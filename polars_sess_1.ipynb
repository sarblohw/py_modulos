# %%
import polars as pl

# %%
df_pl = pl.read_csv('2019.csv')

# %%
df_pl.head(3)
# Out:
# shape: (3, 9)
# ┌────────────┬────────────┬───────┬────────────┬─────┬────────────┬────────────┬──────────┬────────────┐
# │ Overall    ┆ Country or ┆ Score ┆ GDP per    ┆ ... ┆ Healthy    ┆ Freedom to ┆ Generosi ┆ Perception │
# │ rank       ┆ region     ┆ ---   ┆ capita     ┆     ┆ life       ┆ make life  ┆ ty       ┆ s of       │
# │ ---        ┆ ---        ┆ f64   ┆ ---        ┆     ┆ expectancy ┆ choices    ┆ ---      ┆ corruption │
# │ i64        ┆ str        ┆       ┆ f64        ┆     ┆ ---        ┆ ---        ┆ f64      ┆ ---        │
# │            ┆            ┆       ┆            ┆     ┆ f64        ┆ f64        ┆          ┆ f64        │
# ╞════════════╪════════════╪═══════╪════════════╪═════╪════════════╪════════════╪══════════╪════════════╡
# │ 1          ┆ Finland    ┆ 7.769 ┆ 1.34       ┆ ... ┆ 0.986      ┆ 0.596      ┆ 0.153    ┆ 0.393      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# ...

# %%
df_pl.describe()
# Out:
# shape: (7, 10)
# ┌─────┬────────────┬────────────┬──────────┬─────┬────────────┬────────────┬──────────┬────────────┐
# │ des ┆ Overall    ┆ Country or ┆ Score    ┆ ... ┆ Healthy    ┆ Freedom to ┆ Generosi ┆ Perception │
# │ cri ┆ rank       ┆ region     ┆ ---      ┆     ┆ life       ┆ make life  ┆ ty       ┆ s of       │
# │ be  ┆ ---        ┆ ---        ┆ f64      ┆     ┆ expectancy ┆ choices    ┆ ---      ┆ corruption │
# │ --- ┆ f64        ┆ str        ┆          ┆     ┆ ---        ┆ ---        ┆ f64      ┆ ---        │
# │ str ┆            ┆            ┆          ┆     ┆ f64        ┆ f64        ┆          ┆ f64        │
# ╞═════╪════════════╪════════════╪══════════╪═════╪════════════╪════════════╪══════════╪════════════╡
# │ cou ┆ 156.0      ┆ 156        ┆ 156.0    ┆ ... ┆ 156.0      ┆ 156.0      ┆ 156.0    ┆ 156.0      │
# │ nt  ┆            ┆            ┆          ┆     ┆            ┆            ┆          ┆            │
# ...

# %%
df_pl.columns
# Out:
# ['Overall rank',
#  'Country or region',
#  'Score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption']

# %%
df_pl.shape
# Out:
# (156, 9)

# %%
type(df_pl)
# Out:
# polars.internals.dataframe.frame.DataFrame

# %%
dir(pl)
# Out:
# ['ArrowError',
#  'BatchedCsvReader',
#  'Binary',
#  'Boolean',
#  'Categorical',
#  'ComputeError',
#  'Config',
#  'DataFrame',
#  'DataType',
#  'Date',
#  'Datetime',
#  'DuplicateError',
#  'Duration',
#  'Expr',
#  'Field',
#  'Float32',
#  'Float64',
#  'Int16',
#  'Int32',
#  'Int64',
#  'Int8',
#  'InvalidOperationError',
#  'LazyFrame',
#  'List',
#  'NoDataError',
#  'NotFoundError',
#  'Null',
#  'Object',
#  'PanicException',
#  'PolarsDataType',
#  'SQLContext',
#  'SchemaError',
#  'Series',
#  'ShapeError',
#  'StringCache',
#  'Struct',
#  'Time',
#  'UInt16',
#  'UInt32',
#  'UInt64',
#  'UInt8',
#  'Unknown',
#  'Utf8',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_html',
#  'align_frames',
#  'all',
#  'any',
#  'api',
#  'apply',
#  'arange',
#  'arg_where',
#  'argsort_by',
#  'avg',
#  'build_info',
#  'cfg',
#  'coalesce',
# ...

# %%
df_pl.dtypes
# Out:
# [polars.datatypes.Int64,
#  polars.datatypes.Utf8,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64]

# %%
dir(df_pl)
# Out:
# ['__add__',
#  '__annotations__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '_accessors',
#  '_comp',
#  '_compare_to_non_df',
#  '_compare_to_other_df',
#  '_df',
#  '_from_arrow',
#  '_from_dict',
#  '_from_dicts',
#  '_from_numpy',
#  '_from_pandas',
#  '_from_pydf',
#  '_from_records',
#  '_ipython_key_completions_',
#  '_pos_idx',
#  '_pos_idxs',
# ...

# %%
df_pl.to_pandas().describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
df_pl['Score']
# Out:
# shape: (156,)
# Series: 'Score' [f64]
# [
# 	7.769
# 	7.6
# 	7.554
# 	7.494
# 	7.488
# 	7.48
# 	7.343
# 	7.307
# 	7.278
# 	7.246
# 	7.228
# 	7.167
# 	...
# 	3.802
# 	3.775
# 	3.663
# 	3.597
# 	3.488
# 	3.462
# 	3.41
# 	3.38
# 	3.334
# 	3.231
# 	3.203
# 	3.083
# 	2.853
# ]

# %%
df_pl[0]
# Out:
# shape: (1, 9)
# ┌────────────┬────────────┬───────┬────────────┬─────┬────────────┬────────────┬──────────┬────────────┐
# │ Overall    ┆ Country or ┆ Score ┆ GDP per    ┆ ... ┆ Healthy    ┆ Freedom to ┆ Generosi ┆ Perception │
# │ rank       ┆ region     ┆ ---   ┆ capita     ┆     ┆ life       ┆ make life  ┆ ty       ┆ s of       │
# │ ---        ┆ ---        ┆ f64   ┆ ---        ┆     ┆ expectancy ┆ choices    ┆ ---      ┆ corruption │
# │ i64        ┆ str        ┆       ┆ f64        ┆     ┆ ---        ┆ ---        ┆ f64      ┆ ---        │
# │            ┆            ┆       ┆            ┆     ┆ f64        ┆ f64        ┆          ┆ f64        │
# ╞════════════╪════════════╪═══════╪════════════╪═════╪════════════╪════════════╪══════════╪════════════╡
# │ 1          ┆ Finland    ┆ 7.769 ┆ 1.34       ┆ ... ┆ 0.986      ┆ 0.596      ┆ 0.153    ┆ 0.393      │
# └────────────┴────────────┴───────┴────────────┴─────┴────────────┴────────────┴──────────┴────────────┘

# %%
df_pl[['Score', 'Social support']]
# Out:
# shape: (156, 2)
# ┌───────┬────────────────┐
# │ Score ┆ Social support │
# │ ---   ┆ ---            │
# │ f64   ┆ f64            │
# ╞═══════╪════════════════╡
# │ 7.769 ┆ 1.587          │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7.6   ┆ 1.573          │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7.554 ┆ 1.582          │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7.494 ┆ 1.624          │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...   ┆ ...            │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 3.231 ┆ 0.885          │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 3.203 ┆ 0.517          │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 3.083 ┆ 0.0            │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2.853 ┆ 0.575          │
# └───────┴────────────────┘

# %%
df_pl.columns
# Out:
# ['Overall rank',
#  'Country or region',
#  'Score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption']

# %%
df_pl.select(pl.min('Generosity'))
# Out:
# shape: (1, 1)
# ┌────────────┐
# │ Generosity │
# │ ---        │
# │ f64        │
# ╞════════════╡
# │ 0.0        │
# └────────────┘

# %%
df_pl.unique(subset = ['Country or region'])
# Out:
# shape: (156, 9)
# ┌────────────┬────────────┬───────┬────────────┬─────┬────────────┬────────────┬──────────┬────────────┐
# │ Overall    ┆ Country or ┆ Score ┆ GDP per    ┆ ... ┆ Healthy    ┆ Freedom to ┆ Generosi ┆ Perception │
# │ rank       ┆ region     ┆ ---   ┆ capita     ┆     ┆ life       ┆ make life  ┆ ty       ┆ s of       │
# │ ---        ┆ ---        ┆ f64   ┆ ---        ┆     ┆ expectancy ┆ choices    ┆ ---      ┆ corruption │
# │ i64        ┆ str        ┆       ┆ f64        ┆     ┆ ---        ┆ ---        ┆ f64      ┆ ---        │
# │            ┆            ┆       ┆            ┆     ┆ f64        ┆ f64        ┆          ┆ f64        │
# ╞════════════╪════════════╪═══════╪════════════╪═════╪════════════╪════════════╪══════════╪════════════╡
# │ 1          ┆ Finland    ┆ 7.769 ┆ 1.34       ┆ ... ┆ 0.986      ┆ 0.596      ┆ 0.153    ┆ 0.393      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# ...

# %%
df_pl.select(['Score', 'Generosity'])
# Out:
# shape: (156, 2)
# ┌───────┬────────────┐
# │ Score ┆ Generosity │
# │ ---   ┆ ---        │
# │ f64   ┆ f64        │
# ╞═══════╪════════════╡
# │ 7.769 ┆ 0.153      │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7.6   ┆ 0.252      │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7.554 ┆ 0.271      │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7.494 ┆ 0.354      │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...   ┆ ...        │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 3.231 ┆ 0.276      │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 3.203 ┆ 0.158      │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 3.083 ┆ 0.235      │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2.853 ┆ 0.202      │
# └───────┴────────────┘

# %%
df_pl.filter(pl.col('Score') >= 7.225)
# Out:
# shape: (11, 9)
# ┌────────────┬────────────┬───────┬────────────┬─────┬────────────┬────────────┬──────────┬────────────┐
# │ Overall    ┆ Country or ┆ Score ┆ GDP per    ┆ ... ┆ Healthy    ┆ Freedom to ┆ Generosi ┆ Perception │
# │ rank       ┆ region     ┆ ---   ┆ capita     ┆     ┆ life       ┆ make life  ┆ ty       ┆ s of       │
# │ ---        ┆ ---        ┆ f64   ┆ ---        ┆     ┆ expectancy ┆ choices    ┆ ---      ┆ corruption │
# │ i64        ┆ str        ┆       ┆ f64        ┆     ┆ ---        ┆ ---        ┆ f64      ┆ ---        │
# │            ┆            ┆       ┆            ┆     ┆ f64        ┆ f64        ┆          ┆ f64        │
# ╞════════════╪════════════╪═══════╪════════════╪═════╪════════════╪════════════╪══════════╪════════════╡
# │ 1          ┆ Finland    ┆ 7.769 ┆ 1.34       ┆ ... ┆ 0.986      ┆ 0.596      ┆ 0.153    ┆ 0.393      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# ...

# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df = pl.DataFrame(df)

# %%
type(df)
# Out:
# polars.internals.dataframe.frame.DataFrame

# %%
df
# Out:
# shape: (150, 5)
# ┌──────────────┬─────────────┬──────────────┬─────────────┬───────────┐
# │ sepal_length ┆ sepal_width ┆ petal_length ┆ petal_width ┆ species   │
# │ ---          ┆ ---         ┆ ---          ┆ ---         ┆ ---       │
# │ f64          ┆ f64         ┆ f64          ┆ f64         ┆ str       │
# ╞══════════════╪═════════════╪══════════════╪═════════════╪═══════════╡
# │ 5.1          ┆ 3.5         ┆ 1.4          ┆ 0.2         ┆ setosa    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 4.9          ┆ 3.0         ┆ 1.4          ┆ 0.2         ┆ setosa    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 4.7          ┆ 3.2         ┆ 1.3          ┆ 0.2         ┆ setosa    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 4.6          ┆ 3.1         ┆ 1.5          ┆ 0.2         ┆ setosa    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# ...

# %%
df.groupby('species').agg(pl.col('petal_width'))
# Out:
# shape: (3, 2)
# ┌────────────┬─────────────────────┐
# │ species    ┆ petal_width         │
# │ ---        ┆ ---                 │
# │ str        ┆ list[f64]           │
# ╞════════════╪═════════════════════╡
# │ versicolor ┆ [1.4, 1.5, ... 1.3] │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ virginica  ┆ [2.5, 1.9, ... 1.8] │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ setosa     ┆ [0.2, 0.2, ... 0.2] │
# └────────────┴─────────────────────┘

# %%
df.select([pl.col('species') == 'virginica'])
# Out:
# shape: (150, 1)
# ┌─────────┐
# │ species │
# │ ---     │
# │ bool    │
# ╞═════════╡
# │ false   │
# ├╌╌╌╌╌╌╌╌╌┤
# │ false   │
# ├╌╌╌╌╌╌╌╌╌┤
# │ false   │
# ├╌╌╌╌╌╌╌╌╌┤
# │ false   │
# ├╌╌╌╌╌╌╌╌╌┤
# │ ...     │
# ├╌╌╌╌╌╌╌╌╌┤
# │ true    │
# ├╌╌╌╌╌╌╌╌╌┤
# │ true    │
# ├╌╌╌╌╌╌╌╌╌┤
# │ true    │
# ├╌╌╌╌╌╌╌╌╌┤
# │ true    │
# └─────────┘

# %%
pl.col('species')
# Out:
# col("species")
